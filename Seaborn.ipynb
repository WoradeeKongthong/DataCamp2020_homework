# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 1.สร้าง DataFrame ที่เก็บยอดขายของบริษัท A,B,C,D ของปี 2014,2015,2016,2017 โดยชื่อบริษัทเป็น index และปีเป็น column. สร้างคำสั่ง numpy สุ่มเลขแบบ float ให้เป็นรายได้ของบริษัทที่อยู่ในช่วง 50 – 500 (หน่วยล้านบาท)

# %%
companies = ['A', 'B', 'C', 'D']
years = list(range(2014,2018))
sales = np.random.rand(4,4)*450 + 50
df = pd.DataFrame(sales, companies, years)
df
# Out:
#          2014        2015        2016        2017
# A  195.818017  221.311279  121.696288  337.791177
# B  275.893782  439.655453  353.619349  430.926587
# C   56.963191   89.253861  143.678842  229.763028
# D  202.701840  190.090123  382.493390  387.608223

# %% [markdown]
# 2.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Bar plot ให้แกน x เป็น ชื่อบริษัท ยอดขายเฉลี่ยเป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
df['avg'] = df.mean(axis = 1)

# %%
sns.barplot(x = df.index, y = 'avg', data = df)
plt.show()

# %%
sns.barplot(x = 'avg', y = df.index, data = df)
plt.show()

# %% [markdown]
# 3.ใช้ข้อมูลจาก DataFrame ด้านบนสร้าง Scatter plot ให้แกน x เป็น ชื่อบริษัท ยอดขายปี 2017 เป็นแกน Y โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.scatterplot(x = df.index, y = 2017, data = df)
plt.show()

# %%
sns.scatterplot(x = 2017, y = df.index, data = df)
plt.show()

# %% [markdown]
# ให้ import ไฟล์ titanic ไฟล์เดิมจากบทเรียน Pandas เข้าสู่ Jupyter Notebook สามารถใช้ Pandas มาร่วมทำด้วย
#
# 4. สร้าง count plot นับข้อมูล Embarked โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
df2 = pd.read_csv('titanic/train.csv')

# %%
sns.countplot(x = 'Embarked', data = df2)
plt.show()

# %%
sns.countplot(y = 'Embarked', data = df2)
plt.show()

# %% [markdown]
# 5. สร้าง count plot นับข้อมูล Pclass โดยสร้างกราฟแบบแนวตั้งและแนวนอน

# %%
sns.countplot(x = 'Pclass', data = df2)
plt.show()

# %%
sns.countplot(y = 'Pclass', data = df2)
plt.show()

# %% [markdown]
# 6. สร้าง box plot ให้แกน X เป็นเพศ และแกน Y เป็นราคา

# %%
fig = plt.figure(figsize=(4,6))
sns.boxplot(x = 'Sex', y = 'Fare', data = df2)
plt.show()

# %% [markdown]
# 7. สร้าง box plot ให้แกน X เป็นPclass และแกน Y เป็นราคา

# %%
fig = plt.figure(figsize=(6,6))
sns.boxplot(x = 'Pclass', y = 'Fare', data = df2)
plt.show()

# %% [markdown]
# 8. สร้าง barplot โดยให้ แกน X เป็นจุดหมายปลายทางและแกน Y เป็นราคา

# %%
sns.barplot(x = 'Embarked', y = 'Fare', data = df2)
plt.show()

# %% [markdown]
# 9. สร้าง barplot โดยให้ แกน X เป็นPclass และแกน Y เป็นอายุ

# %%
sns.barplot(x = 'Pclass', y = 'Age', data = df2)
plt.show()

# %% [markdown]
# 10. สร้าง Stripplot โดยให้แกน X เป็น Pclass และ แกน Y เป็นราคา

# %%
sns.stripplot(x = 'Pclass', y = 'Fare', data = df2)
plt.show()

# %% [markdown]
# 11. สร้าง Stripplot โดยให้ แกน X เป็น Survived แกน Y เป็นอายุ และ hue เป็นเพศ

# %%
fig = plt.figure(figsize=(6,10))
sns.stripplot(x = 'Survived', y = 'Age', data = df2, hue = 'Sex')
plt.show()

# %% [markdown]
# 12. สร้าง Swarmplot โดยให้ แกน X เป็นเพศและแกน Y เป็นอายุ

# %%
fig = plt.figure(figsize=(6,8))
sns.swarmplot(x = 'Sex', y = 'Age', data = df2)
plt.show()

# %% [markdown]
# 13. สร้าง HeatMap โดย crosstab กำหนดให้ index เป็น Pclass และ column เป็นเพศ

# %%
df3 = pd.crosstab(df2['Pclass'], df2['Sex'])
df3
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
fig = plt.figure(figsize=(5,5))
sns.heatmap(df3,cmap='Blues', annot=True, fmt='d')
plt.show()

# %% [markdown]
# 14. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา

# %%
df4 = df2.pivot_table(index = 'Pclass', columns = 'Sex', values = 'Fare')
sns.heatmap(df4, cmap='Blues', annot=True, fmt= 'f')
plt.show()

# %% [markdown]
# 15. สร้าง HeatMap โดย pivot table กำหนดให้ index เป็น Pclass และ column เป็นเพศ และ values เป็น ราคา และกำหนดเส้นสีขาวขนาด 2 เป็นเส้นแบ่ง

# %%
sns.heatmap(df4, cmap='Blues', annot=True, fmt='f', linewidth=2, linecolor='white')
plt.show()

# %% [markdown]
# 16. สร้าง Heatmap โดย Correlation ของทั้ง DataFrame

# %%
df5 = df2.corr()
sns.heatmap(df5, cmap='Blues')
plt.show()

# %% [markdown]
# 17. สร้าง Clustermap ของทั้ง DataFrame

# %%
sns.clustermap(df5, cmap='Blues', annot=True)
plt.show()

# %% [markdown]
# 18. พิจารณาจากข้อมูลที่มีความสัมพันธ์มากที่สุดมาสร้าง Scatterplot

# %%
sns.scatterplot(x='SibSp', y='Parch', data=df2)
plt.show()

# %% [markdown]
# 19. พิจารณาจากข้อมูลที่มีความสัมพันธ์น้อยที่สุดมาสร้าง Scatterplot และให้ hue เป็นเพศ

# %%
# ข้อมูลที่มีความสัมพันธ์แบบ strong-negative
sns.scatterplot(x='Pclass', y='Fare', hue='Sex', data=df2)
plt.show()

# %%
# ข้อมูลที่แทบไม่มีความสัมพันธ์กันเลย (correlation ~ 0)
sns.scatterplot(x='Pclass', y='Fare', hue='Sex', data=df2)
plt.show()

# %% [markdown]
# 20. สร้าง Distribution Plot ของราคาและอายุ

# %%
fig = plt.figure(figsize=(10,4))
sns.distplot(df2['Fare'])
plt.show()

# %%
sns.distplot(df2['Age'])
plt.show()

# %% [markdown]
# 21. สร้าง Pair Plot ของทั้ง DataFrame (หรือ column ที่น่าสนใจ)

# %%
sns.pairplot(df2)
plt.show()
